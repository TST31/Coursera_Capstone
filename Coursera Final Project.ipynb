# %% [markdown]
# # Neighborhood Analysis of a German City for Young Families
# We'll investigate the neighborhood in a German City, including the venues and try to find the best spot possible to move for families with children. As measurement we choose the distance to child-important venues like schools, playgrounds and medical care.

# %% [markdown]
# ## Description of the problem
# Young families with children or plans for some are frequently in the situation to find a new place to call home, that will give their changing life as a family the best possible neighborhood.
# Identification is not an easy task, as there are multiple factors to be included and not all information readily available. As a support for their decision making, we want to provide a geographical analysis of children-friendly neighboorhoods based on the distance to desired venues. For example the new home must be near a school, but also provide a playground for leasure time.
# We'll focus on the German City Wermelskirchen out of curiosity.

# %% [markdown]
# ## Description of the data
# As dataset we're using a publicly available dataset of the German City Wuppertal, including it's districts and several population metrics.

# %% [markdown]
# https://de.wikipedia.org/wiki/Liste_der_Stadtbezirke_und_Stadtteile_von_Wuppertal
#
# The original table is looking like:
# <img src="pic1.png">
#
# In the process of preperation we'll be translating and transforming the data. Please bear with me for now, but the relevant data is the following:
# - 'Neighborhood'
# - 'Borough'
# - 'Residents'
# - 'Size'
# - 'Population_Density'
# - 'Foreigner_Percentage'
# - 'Unemployment_Rate'
# - 'Livinghouses'
# - 'Flats_thereof'
# - 'Schools(Elementary_Schools)'
# - 'Private_Cars'

# %% [markdown]
# Additionally we'll use the also publicy available GEOJSON data for these districts including their geographic boundaries.
# Url: http://daten.wuppertal.de/Infrastruktur_Bauen_Wohnen/Quartiere_EPSG4326_JSON.json
#
# <img src="pic2.png">

# %% [markdown]
# Furthermore we'll connect to the foursquare database and use data for venues from there.

# %% [markdown]
# ## Methodology section

# %% [markdown]
# For the analysis we'll use several fairly standard python packages.

# %%
# Standards
import pandas as pd
import numpy as np

# Online interfaces for data fetching
import requests
from bs4 import BeautifulSoup

# Machine learning
from sklearn.cluster import KMeans

# Data visualization
import folium # map rendering library
import matplotlib.cm as cm
import matplotlib.colors as colors

# Geodata manipulation
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geojson
from shapely.geometry import shape

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Fetch and initially clean data from Wikipedia

# %%
d_wiki = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_Stadtbezirke_und_Stadtteile_von_Wuppertal#Die_Wohnquartiere_Wuppertals_(Stand:_31._Dezember_2007)", decimal=',', thousands='.')[2]

# %% [markdown]
# We'll not need some of the columns.

# %%
print(d_wiki.columns)
d_wiki.drop(["Karte[4]", "Nr.", "Kommunale Zuordnung vor der Eingemeindung"], axis=1, inplace=True)
# Out:
# Index(['Karte[4]', 'Nr.', 'Statistisches Wohnquartier', 'Stadtbezirk',
#        'Kommunale Zuordnung vor der Eingemeindung', 'Einwohner-zahl',
#        'Fläche( km² )', 'Bevölkerungs-dichte(Einw. / km² )',
#        'Ausländer-anteil (in %)', 'Arbeitslosen-quote (in %)', 'Wohn-gebäude',
#        'darin Wohnungen', 'Schulen(davonGrundschulen)', 'PrivateKFZ'],
#       dtype='object')

# %% [markdown]
# For everyone to understand the data, we're translating it from German to English.

# %%
d_wiki.rename(columns={"Statistisches Wohnquartier": "Neighborhood", "Stadtbezirk": "Borough", "Einwohner-zahl": "Residents", d_wiki.columns[3]: "Size", d_wiki.columns[4]: "Population_Density", d_wiki.columns[5]: "Foreigner_Percentage", d_wiki.columns[6]: "Unemployment_Rate", "Wohn-gebäude": "Livinghouses", d_wiki.columns[8]: "Flats_thereof", "Schulen(davonGrundschulen)": "Schools(Elementary_Schools)", "PrivateKFZ": "Private_Cars"}, inplace=True)
d_wiki.columns
# Out:
# Index(['Neighborhood', 'Borough', 'Residents', 'Size', 'Population_Density',
#        'Foreigner_Percentage', 'Unemployment_Rate', 'Livinghouses',
#        'Flats_thereof', 'Schools(Elementary_Schools)', 'Private_Cars'],
#       dtype='object')

# %% [markdown]
# The schools column actually contains two data, the number of schools in total and the number of elementary schools there of. For the sake of simplicity we'll split this into two columns, by regextracting the elementary schools.

# %%
d_wiki["Elementary_Schools"] = d_wiki["Schools(Elementary_Schools)"].str.extract(r"\((.)\)")
d_wiki["Elementary_Schools"] = d_wiki["Elementary_Schools"].astype(str).str.replace("-", "0").astype(int)
d_wiki["Schools(Elementary_Schools)"] = d_wiki["Schools(Elementary_Schools)"].str.extract(r"(.*)(?=\()")
d_wiki.rename(columns={"Schools(Elementary_Schools)": "Schools"}, inplace=True)

# %% [markdown]
# Due to the split of the schools column it's of type object due to the "-".

# %%
d_wiki["Schools"] = d_wiki["Schools"].replace("- ","0").astype(int)

# %% [markdown]
# The percentage values miss the point.

# %%
d_wiki["Foreigner_Percentage"] = d_wiki["Foreigner_Percentage"]/10
d_wiki["Unemployment_Rate"] = d_wiki["Unemployment_Rate"]/100

# %% [markdown]
# The final table of neighborhoods looks like this:

# %%
d_wiki
# Out:
#               Neighborhood                Borough  Residents   Size  \
# 0          Elberfeld-Mitte              Elberfeld       5780   1.08
# 1                Nordstadt              Elberfeld      17269   1.18
# 2               Ostersbaum              Elberfeld      14919   1.38
# 3                 Südstadt              Elberfeld       9640   0.59
# 4             Grifflenberg              Elberfeld      11696   4.45
# 5           Friedrichsberg              Elberfeld       6449   2.39
# 6                 Sonnborn         Elberfeld-West       4008   2.39
# 7               Varresbeck         Elberfeld-West       4376   2.59
# 8               Nützenberg         Elberfeld-West       5590   1.48
# 9                    Brill         Elberfeld-West       4414   1.22
# 10               Arrenberg         Elberfeld-West       5449   0.86
# 11                     Zoo         Elberfeld-West       3871   2.32
# 12             Buchenhofen         Elberfeld-West         66   0.88
# 13         Uellendahl-West  Uellendahl-Katernberg       9741   2.61
# 14          Uellendahl-Ost  Uellendahl-Katernberg       6501   2.42
# 15                 Dönberg  Uellendahl-Katernberg       5082   6.39
# 16        Nevigeser Straße  Uellendahl-Katernberg       6940   2.39
# 17                    Beek  Uellendahl-Katernberg       2975   1.75
# 18                Eckbusch  Uellendahl-Katernberg       4594   5.30
# 19              Siebeneick  Uellendahl-Katernberg       2359   5.05
# 20         Vohwinkel-Mitte              Vohwinkel       9145   1.48
# 21               Osterholz              Vohwinkel       4062   1.96
# 22                  Tesche              Vohwinkel       3911   1.34
# 23         Schöller-Dornap              Vohwinkel       2991   8.08
# 24              Lüntenbeck              Vohwinkel       1113   1.32
# 25         Industriestraße              Vohwinkel        196   0.70
# 26                Westring              Vohwinkel       3971   2.29
# 35            248        0           397                   0
# 36           2829        1          1432                   0
# 37           4191        2          2440                   1
# 38           2784        1          1737                   1
# 39           1505        1          1334                   0
# 40           5839        6          3856                   2
# 41           5943        4          3949                   2
# 42           2204        0          2399                   0
# 43           5014        4          3681                   1
# 44           1546        1           946                   1
# 45           2160        1          2388                   1
# 46           7187        4          4222                   2
# 47           5559        4          3525                   2
# 48           3082        2          2358                   1
# 49           3319        1          2918                   1
# 50           3683        2          4349                   2
# 51           7165        2          5042                   1
# 52           4309        1          3170                   1
# 53            676        1           802                   1
# 54           2708        3          2053                   2
# 55           1958        0          1674                   0
# 56           1008        0           809                   0
# 57           1681        2          1277                   1
# 58           1018        0           763                   0
# 59           1141        1           943                   1
# 60           1256        0          1494                   0
# 61           1528        1          1954                   1
# 62           1149        0          1585                   0
# 63           4144        1          4329                   1
# 64           1521        1          1526                   1
# 65            993        0           750                   0
# 66           1785        1          1769                   1
# 67           2458        3          2821                   2
# 68            395        0           624                   0

# %% [markdown]
# ### Fetch Geojson data for district boundaries

# %%
url = r'http://daten.wuppertal.de/Infrastruktur_Bauen_Wohnen/Quartiere_EPSG4326_JSON.json' # geojson file
geojson = requests.get(url).json()

# %% [markdown]
# Let's check, whether the naming of districts is the same as in the Wikipedia data:

# %%
geojson_df = pd.read_json("http://daten.wuppertal.de/Infrastruktur_Bauen_Wohnen/Quartiere_EPSG4326_JSON.json")
geojson_districts = []
for i in geojson_df["features"]:
    geojson_districts.append(i["properties"]["NAME"])
geojson_districts.sort()

# %%
data_pre = {"wiki_neighborhoods": d_wiki["Neighborhood"].sort_values(), "GEOJSON_neighborhoods": geojson_districts}
comparison = pd.DataFrame(data_pre).reset_index(drop=True)
comparison.loc[comparison["wiki_neighborhoods"]==comparison["GEOJSON_neighborhoods"], "HIT"] = True
comparison.loc[comparison["wiki_neighborhoods"]!=comparison["GEOJSON_neighborhoods"], "HIT"] = False

# %%
comparison[comparison["HIT"]==False]
# Out:
#         wiki_neighborhoods GEOJSON_neighborhoods    HIT
# 10        Cronenberg-Mitte            Cronenberg  False
# 15         Elberfeld-Mitte             Elberfeld  False
# 18  Friedrich-Engels-Allee      Fr.-Engels-Allee  False
# 30         Industriestraße         Industriestr.  False
# 31     Jesinghauser Straße     Jesinghauser Str.  False
# 40        Nevigeser Straße         Nevigeser Str  False
# 52            Schenkstraße            Schenkstr.  False

# %% [markdown]
# There are a few cases, we have to harmonize in order to make both datasets comparable. We'll choose to go with the GEOJSON convention.

# %%
d_wiki = d_wiki.merge(comparison, left_on='Neighborhood', right_on="wiki_neighborhoods", how="left")
d_wiki.loc[d_wiki["HIT"]==False, 'Neighborhood'] = d_wiki.loc[d_wiki["HIT"]==False, 'GEOJSON_neighborhoods']
d_wiki.drop(["wiki_neighborhoods","GEOJSON_neighborhoods", "HIT"], inplace=True, axis=1)

# %% [markdown]
# ### Fetch foursquare data for Wuppertal

# %% [markdown]
# We'll need to set some parameters for the foursquare API.

# %%
CLIENT_ID = "SBLODBLCGZNT4MIP04BPKDRDIMQETLUIWVMD0H5KAH5OHPWS"
CLIENT_SECRET = "0BF4FQMSHJ5BASM1USWS0FARALO04VMN2WM34WOGXKYJ5D3G"
version = "20200110"
base_url = "https://api.foursquare.com/v2/venues/search?"
LIMIT = 100
radius = 5000

# %% [markdown]
# Fetch the district centers:

# %%
collection = requests.get('http://daten.wuppertal.de/Infrastruktur_Bauen_Wohnen/Quartiere_EPSG4326_JSON.json').json()
features = collection["features"]
centers = {}
for feature in features:
    s = shape(feature["geometry"]).centroid
    centers[feature["properties"]["NAME"]] = (s.x, s.y)

# %%
centers2 = pd.DataFrame(centers).transpose().reset_index()
centers2.rename(columns={"index": "Neighborhood", 1: "Latitude", 0: "Longitude"}, inplace=True)
d_wiki = pd.merge(d_wiki, centers2, on="Neighborhood", how="left")

# %% [markdown]
# Using the function from the lab to fetch venues for given neighborhoods.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            version, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    try:
        nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    except:
        print("Error encountered")
    
    return(nearby_venues)

# %%
#wuppertal_venues = getNearbyVenues(names=d_wiki["Neighborhood"], latitudes=d_wiki["Latitude"], longitudes=d_wiki["Longitude"])

# %%
#wuppertal_venues.to_csv("wuppertal_venues.csv")
wuppertal_venues = pd.read_csv("wuppertal_venues.csv")

# %%
category_count = wuppertal_venues[["Neighborhood", "Venue Category", "Venue"]].groupby(["Neighborhood", "Venue Category"], as_index=False).count()

# %%
category_count["Venue Category"].value_counts()
# Out:
# Supermarket                   14
# Bus Stop                      12
# Café                          11
# Construction & Landscaping    10
# Cable Car                      8
# Bakery                         8
# Plaza                          8
# Hotel                          6
# Fast Food Restaurant           5
# Clothing Store                 5
# German Restaurant              4
# Electronics Store              4
# Restaurant                     4
# Pizza Place                    4
# Gas Station                    4
# Drugstore                      4
# Intersection                   4
# Business Service               3
# BBQ Joint                      3
# Train Station                  3
# Chinese Restaurant             3
# Gym                            3
# Furniture / Home Store         3
# Liquor Store                   3
# Ice Cream Shop                 3
# Bar                            2
# Asian Restaurant               2
# Playground                     2
# Steakhouse                     2
# Greek Restaurant               2
# Gastropub                      2
# Camera Store                   2
# Recreation Center              2
# Cocktail Bar                   2
# Bus Station                    2
# Italian Restaurant             2
# Grocery Store                  2
# Department Store               2
# Home Service                   2
# Hookah Bar                     2
# Soccer Field                   2
# Trail                          2
# Turkish Restaurant             2
# Print Shop                     2
# Bank                           2
# Park                           2
# Theater                        2
# Platform                       2
# Mexican Restaurant             2
# Gym / Fitness Center           2
# Insurance Office               1
# Zoo                            1
# Burger Joint                   1
# Hardware Store                 1
# Convenience Store              1
# Beach                          1
# Event Service                  1
# Hobby Shop                     1
# Modern European Restaurant     1
# Monument / Landmark            1
# Rock Climbing Spot             1
# Warehouse Store                1
# Zoo Exhibit                    1
# Farm                           1
# Wine Shop                      1
# Beer Bar                       1
# Garden Center                  1
# Automotive Shop                1
# Mobile Phone Shop              1
# Snack Place                    1
# Discount Store                 1
# Pub                            1
# Stationery Store               1
# Health & Beauty Service        1
# Art Museum                     1
# Sculpture Garden               1
# Shopping Mall                  1
# Coffee Shop                    1
# Light Rail Station             1
# Palace                         1
# Mediterranean Restaurant       1
# Forest                         1
# Doner Restaurant               1
# Comfort Food Restaurant        1
# Grilled Meat Restaurant        1
# Pet Store                      1
# Big Box Store                  1
# Food & Drink Shop              1
# Town Hall                      1
# Bookstore                      1
# Spanish Restaurant             1
# Brewery                        1
# Rest Area                      1
# Soccer Stadium                 1
# Auto Workshop                  1
# Nature Preserve                1
# Sandwich Place                 1
# Food                           1
# Tram Station                   1
# Thai Restaurant                1
# Lake                           1
# ATM                            1
# Middle Eastern Restaurant      1
# Fried Chicken Joint            1
# Martial Arts School            1
# Music Venue                    1
# Cafeteria                      1
# Botanical Garden               1
# Garden                         1
# Diner                          1
# Climbing Gym                   1
# Science Museum                 1
# Name: Venue Category, dtype: int64

# %%
kids_stuff = ["Ice Cream Shop", "Park", "Playground", "Soccer Field", "Rest Area", "Beach", "Sculpture Garden", "Botanical Garden", "Zoo Exhibit", "Rock Climbing Spot", "Forest", "Nature Preserve", "Lake", "Zoo", "Pet Store", "Garden"]
anti_kids_stuff = ["Intersection", "Liquor Store", "Gastropub", "Cocktail Bar", "Hookah Bar", "Bar", "Beer Bar", "Nightclub", "Light Rail Station", "Train Station", "Pub", "Lottery Retailer", "Bridge", "Hostel", "Smoke Shop"]

# %%
category_count.loc[category_count["Venue Category"].isin(kids_stuff), "Kids_friendly"] = 1
category_count.loc[category_count["Venue Category"].isin(anti_kids_stuff), "Kids_unfriendly"] = 1

# %%
category_count2 = category_count[["Neighborhood", "Kids_friendly", "Kids_unfriendly"]].groupby("Neighborhood").sum()
category_count2["Total"] = category_count2["Kids_friendly"] - category_count2["Kids_unfriendly"]
category_count2 = category_count2.sort_values(by="Total", ascending=False).reset_index(drop=False)
category_count2
# Out:
#               Neighborhood  Kids_friendly  Kids_unfriendly  Total
# 0                      Zoo            2.0              0.0    2.0
# 1               Ostersbaum            2.0              0.0    2.0
# 2               Siebeneick            1.0              0.0    1.0
# 3                Kohlfurth            1.0              0.0    1.0
# 4                     Höhe            1.0              0.0    1.0
# 5              Hilgershöhe            1.0              0.0    1.0
# 6              Hesselnberg            1.0              0.0    1.0
# 7        Nächstebreck-West            1.0              0.0    1.0
# 8                 Rauental            1.0              0.0    1.0
# 9             Barmen-Mitte            1.0              0.0    1.0
# 10                    Rott            1.0              0.0    1.0
# 11                  Kothen            1.0              0.0    1.0
# 12      Wichlinghausen-Süd            2.0              1.0    1.0
# 13              Varresbeck            1.0              0.0    1.0
# 14               Blutfinke            1.0              0.0    1.0
# 15              Sedansberg            0.0              0.0    0.0
# 16              Lüntenbeck            0.0              0.0    0.0
# 17            Lichtenplatz            0.0              0.0    0.0
# 18                     Loh            0.0              0.0    0.0
# 19                Westring            0.0              0.0    0.0
# 20         Vohwinkel-Mitte            0.0              0.0    0.0
# 21           Nevigeser Str            0.0              0.0    0.0
# 22              Schenkstr.            0.0              0.0    0.0
# 23        Nächstebreck-Ost            0.0              0.0    0.0
# 24               Osterholz            0.0              0.0    0.0
# 25         Uellendahl-West            0.0              0.0    0.0
# 26                  Tesche            1.0              1.0    0.0
# 27                Südstadt            0.0              0.0    0.0
# 28                 Sudberg            1.0              1.0    0.0
# 29     Ronsdorf-Mitte/Nord            0.0              0.0    0.0
# 30              Küllenhahn            0.0              0.0    0.0
# 31         Beyenburg-Mitte            0.0              0.0    0.0
# 32              Cronenfeld            0.0              0.0    0.0
# 33               Ehrenberg            0.0              0.0    0.0
# 34                 Clausen            0.0              0.0    0.0
# 35          Erbschlö-Linde            0.0              0.0    0.0
# 36             Buchenhofen            0.0              0.0    0.0
# 37                   Brill            0.0              0.0    0.0
# 38      Blombach-Lohsiepen            0.0              0.0    0.0
# 39              Hahnerberg            0.0              0.0    0.0
# 40                 Dönberg            0.0              0.0    0.0
# 41              Hammesberg            0.0              0.0    0.0
# 42                Hatzfeld            0.0              0.0    0.0
# 43              Berghausen            0.0              0.0    0.0
# 44           Heckinghausen            0.0              0.0    0.0
# 45                   Heidt            0.0              0.0    0.0
# 46           Industriestr.            0.0              0.0    0.0
# 47     Wichlinghausen-Nord            0.0              1.0   -1.0
# 48              Cronenberg            0.0              1.0   -1.0
# 49        Langerfeld-Mitte            0.0              1.0   -1.0
# 50               Elberfeld            1.0              2.0   -1.0
# 51          Schrödersbusch            0.0              1.0   -1.0
# 52       Jesinghauser Str.            0.0              1.0   -1.0
# 53                  Fleute            0.0              1.0   -1.0
# 54        Fr.-Engels-Allee            0.0              1.0   -1.0
# 55            Grifflenberg            0.0              1.0   -1.0
# 56  Oberbarmen-Schwarzbach            0.0              1.0   -1.0
# 57              Nützenberg            0.0              1.0   -1.0
# 58                Sonnborn            0.0              2.0   -2.0
# 59               Nordstadt            0.0              2.0   -2.0
# 60               Arrenberg            0.0              2.0   -2.0

# %% [markdown]
# ### Initial analysis of the neighborhoods

# %% [markdown]
# First let's look into the wikipedia data on the neighborhoods, by aggregating on the boroughs and getting a feeling for their characteristics.

# %%
d_wiki[["Borough", "Neighborhood", "Size", "Residents", "Foreigner_Percentage", "Unemployment_Rate", 'Livinghouses',
       'Flats_thereof', 'Schools', 'Private_Cars', 'Elementary_Schools']].groupby('Borough').agg({'Neighborhood': "count", 
                         'Size':'sum', 
                         'Residents':'sum', 
                         'Foreigner_Percentage': "mean",
                         "Unemployment_Rate": "mean",
                         "Livinghouses": "sum",
                         "Flats_thereof": "sum",
                         "Schools": "sum",
                         "Elementary_Schools": "sum",
                         "Private_Cars": "sum"
                    }).sort_values(by="Residents", ascending=False)
# Out:
#                        Neighborhood   Size  Residents  Foreigner_Percentage  \
# Borough
# Elberfeld                         6  11.07      65753              2.006667
# Barmen                           10  15.44      59410              1.466000
# Oberbarmen                        5  12.57      42910              1.460000
# Uellendahl-Katernberg             7  25.91      38192              0.524286
# Vohwinkel                         9  20.42      31578              0.920000
# Elberfeld-West                    7  11.74      27774              1.372857
# Langerfeld-Beyenburg              9  29.40      25517              0.955556
# Cronenberg                        7  21.50      21846              0.490000
# Ronsdorf                          6  16.05      21776              0.588333
# Heckinghausen                     3   5.66      21261              1.163333
#
#                        Unemployment_Rate  Livinghouses  Flats_thereof  \
# Borough
# Elberfeld                       0.075800          6686          39128
# Barmen                          0.059770          7403          34015
# Oberbarmen                      0.066640          5511          22830
# Uellendahl-Katernberg           0.025857          7713          19619
# Vohwinkel                       0.037956          5328          15732
# Elberfeld-West                  0.050100          4243          15895
# Langerfeld-Beyenburg            0.058256          4560          13447
# Cronenberg                      0.025729          4996          11102
# Ronsdorf                        0.035267          4141          11296
# Heckinghausen                   0.054267          2555          12150
#
#                        Schools  Elementary_Schools  Private_Cars
# Borough
# Elberfeld                   18                  10         22121
# Barmen                      21                   9         24162
# Oberbarmen                  13                   8         17372
# Uellendahl-Katernberg        9                   7         21174
# Vohwinkel                   12                   6         14652
# Elberfeld-West               8                   6         12784
# Langerfeld-Beyenburg         7                   5         12552
# Cronenberg                   7                   4         12881
# Ronsdorf                     6                   5         11819
# Heckinghausen                4                   3          9014

# %% [markdown]
# Then let's shortly visualize the map including the neighborhoods, by drawing a choropleth-map based on the residents.

# %%
# create a numpy array of length 6 and has linear spacing from the minium total immigration to the maximum total immigration
threshold_scale = np.linspace(d_wiki['Residents'].min(),
                              d_wiki['Residents'].max(),
                              6, dtype=int)
threshold_scale = threshold_scale.tolist() # change the numpy array to a list
threshold_scale[-1] = threshold_scale[-1] + 1 # make sure that the last value of the list is greater than the maximum immigration

# let Folium determine the scale.
world_map = folium.Map(location=[51.256214, 7.150764], zoom_start=11)
world_map.choropleth(
    geo_data=geojson,
    data=d_wiki,
    columns=['Neighborhood', 'Residents'],
    key_on='feature.properties.NAME',
    threshold_scale=threshold_scale,
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Residents',
    reset=True
)
world_map
# Out:
# /Users/a1/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9f3b469d06bd43689b3fa1872e2c9968%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9f3b469d06bd43689b3fa1872e2c9968%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9f3b469d06bd43689b3fa1872e2c9968%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9f3b469d06bd43689b3fa1872e2c9968%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## k-means clustering of neighborhoods by venues

# %% [markdown]
# First we'll reduce the number of categories and aggregate them on a higher level.

# %%
wuppertal_venues["Venue Category"].value_counts()
# Out:
# Supermarket                   18
# Café                          17
# Bus Stop                      14
# Bakery                        13
# Construction & Landscaping    11
# Clothing Store                10
# Hotel                          9
# Cable Car                      9
# Plaza                          8
# Drugstore                      8
# Fast Food Restaurant           6
# Restaurant                     6
# Pizza Place                    5
# Platform                       4
# German Restaurant              4
# Intersection                   4
# Gas Station                    4
# Electronics Store              4
# Ice Cream Shop                 4
# Italian Restaurant             4
# Business Service               3
# Park                           3
# Cocktail Bar                   3
# BBQ Joint                      3
# Liquor Store                   3
# Chinese Restaurant             3
# Theater                        3
# Furniture / Home Store         3
# Coffee Shop                    3
# Gym                            3
# Train Station                  3
# Bus Station                    2
# Camera Store                   2
# Department Store               2
# Greek Restaurant               2
# Grocery Store                  2
# Playground                     2
# Recreation Center              2
# Gastropub                      2
# Bar                            2
# Steakhouse                     2
# Home Service                   2
# Soccer Field                   2
# Trail                          2
# Gym / Fitness Center           2
# Bank                           2
# Burger Joint                   2
# Mexican Restaurant             2
# Turkish Restaurant             2
# Hookah Bar                     2
# Shopping Mall                  2
# Asian Restaurant               2
# Print Shop                     2
# Event Service                  1
# Garden Center                  1
# Monument / Landmark            1
# Hardware Store                 1
# Warehouse Store                1
# Zoo Exhibit                    1
# Zoo                            1
# Convenience Store              1
# Modern European Restaurant     1
# Automotive Shop                1
# Hobby Shop                     1
# Brewery                        1
# Climbing Gym                   1
# Mobile Phone Shop              1
# Beer Bar                       1
# Food                           1
# Pub                            1
# Stationery Store               1
# Sculpture Garden               1
# Art Museum                     1
# Snack Place                    1
# Farm                           1
# Health & Beauty Service        1
# Discount Store                 1
# Insurance Office               1
# Beach                          1
# Town Hall                      1
# Rock Climbing Spot             1
# Pet Store                      1
# Wine Shop                      1
# Rest Area                      1
# Bookstore                      1
# Nature Preserve                1
# Food & Drink Shop              1
# Garden                         1
# Light Rail Station             1
# Grilled Meat Restaurant        1
# Spanish Restaurant             1
# Comfort Food Restaurant        1
# Doner Restaurant               1
# Forest                         1
# Palace                         1
# Soccer Stadium                 1
# Auto Workshop                  1
# Martial Arts School            1
# Big Box Store                  1
# Diner                          1
# Botanical Garden               1
# Music Venue                    1
# Fried Chicken Joint            1
# Sandwich Place                 1
# Middle Eastern Restaurant      1
# Cafeteria                      1
# Lake                           1
# Thai Restaurant                1
# ATM                            1
# Science Museum                 1
# Tram Station                   1
# Mediterranean Restaurant       1
# Name: Venue Category, dtype: int64

# %%
shops = ["Supermarket", "Drugstore", "Bakery", "Clothing Store", "Coffe Shop", "Ice Cream Shop", "Grocery Store", "Big Box Store", "Electronics Store", "Sporting Goods Shop", "Pharmacy", "Shopping Mall", "Convenience Store", "Organic Grocery", "Bookstore", "Paper / Office Supplies Store", "Hardware Store", "Stationery Store", "Automotive Shop", "Discount Store", "Hobby Shop", "Furniture / Home Store", "Farmers Market", "Miscellaneous Shop", "Shoe Store", "Flea Market", "Mobile Phone Shop", "Department Store", "Camera Store", "Photography Studio", "Tailor Shop", "Fruit & Vegetable Store"]
kids_unfriendly = ["Intersection", "Liquor Store", "Gastropub", "Cocktail Bar", "Hookah Bar", "Bar", "Beer Bar", "Nightclub", "Light Rail Station", "Train Station", "Pub", "Lottery Retailer", "Bridge", "Hostel", "Smoke Shop"]
imbiss = ["Café", "Fast Food Restaurant", "Pizza Place", "Diner", "Sandwich Place", "Burger Joint", "Snack Place", "Bistro", "Doner Restaurant", "Fried Chicken Joint", "Food & Drink Shop"]
restaurant = ["Japanese Restaurant", "Scandinavian Restaurant", "American Restaurant", "Steakhouse", "Asian Restaurant", "Falafel Restaurant", "Modern European Restaurant", "Mexican Restaurant", "Korean Restaurant", "Grilled Meat Restaurant", "Turkish Restaurant", "Spanish Restaurant", "Chinese Restaurant", "Greek Restaurant", "BBQ Joint", "German Restaurant", "Restaurant", "Italian Restaurant"]
activities = ["Park", "Plaza", "Pool", "Trail", "Soccer Field", "Golf Course", "Botanical Garden", "Sculpture Garden", "Climbing Gym", "Zoo", "Zoo Exhibit", "Water Park", "Theater", "Sports Club", "Lake"]
hotels = ["Hotel", "Hostel"]

wuppertal_venues.loc[wuppertal_venues["Venue Category"].isin(shops), "Category"] = "Rest"
wuppertal_venues.loc[wuppertal_venues["Venue Category"].isin(kids_unfriendly), "Category"] = "Unfriendly"
wuppertal_venues.loc[wuppertal_venues["Venue Category"].isin(imbiss), "Category"] = "Rest"
wuppertal_venues.loc[wuppertal_venues["Venue Category"].isin(restaurant), "Category"] = "Rest"
wuppertal_venues.loc[wuppertal_venues["Venue Category"].isin(activities), "Category"] = "Activity"
wuppertal_venues.loc[wuppertal_venues["Venue Category"].isin(hotels), "Category"] = "Rest"
wuppertal_venues.loc[wuppertal_venues["Category"]!=wuppertal_venues["Category"], "Category"] = "Rest"
wuppertal_venues
# Out:
#      Unnamed: 0            Neighborhood  Neighborhood Latitude  \
# 0             0               Elberfeld              51.255741
# 1             1               Elberfeld              51.255741
# 2             2               Elberfeld              51.255741
# 3             3               Elberfeld              51.255741
# 4             4               Elberfeld              51.255741
# 5             5               Elberfeld              51.255741
# 6             6               Elberfeld              51.255741
# 7             7               Elberfeld              51.255741
# 8             8               Elberfeld              51.255741
# 9             9               Elberfeld              51.255741
# 10           10               Elberfeld              51.255741
# 11           11               Elberfeld              51.255741
# 12           12               Elberfeld              51.255741
# 13           13               Elberfeld              51.255741
# 14           14               Elberfeld              51.255741
# 15           15               Elberfeld              51.255741
# 16           16               Elberfeld              51.255741
# 17           17               Elberfeld              51.255741
# 18           18               Elberfeld              51.255741
# 19           19               Elberfeld              51.255741
# 20           20               Elberfeld              51.255741
# 21           21               Elberfeld              51.255741
# 22           22               Elberfeld              51.255741
# 23           23               Elberfeld              51.255741
# 24           24               Elberfeld              51.255741
# 25           25               Elberfeld              51.255741
# 26           26               Elberfeld              51.255741
# 27           27               Elberfeld              51.255741
# 28           28               Elberfeld              51.255741
# 29           29               Elberfeld              51.255741
# 30           30               Elberfeld              51.255741
# 31           31               Elberfeld              51.255741
# 32           32               Elberfeld              51.255741
# 33           33               Elberfeld              51.255741
# 34           34               Elberfeld              51.255741
# 35           35               Elberfeld              51.255741
# 36           36               Elberfeld              51.255741
# 37           37               Elberfeld              51.255741
# 38           38               Elberfeld              51.255741
# 39           39               Elberfeld              51.255741
# 40           40               Elberfeld              51.255741
# 41           41               Elberfeld              51.255741
# 42           42               Elberfeld              51.255741
# 43           43               Elberfeld              51.255741
# 44           44               Elberfeld              51.255741
# 45           45               Elberfeld              51.255741
# 46           46               Elberfeld              51.255741
# 47           47               Elberfeld              51.255741
# 48           48               Elberfeld              51.255741
# 49           49               Elberfeld              51.255741
# 50           50               Elberfeld              51.255741
# 51           51               Elberfeld              51.255741
# 52           52               Elberfeld              51.255741
# 53           53               Elberfeld              51.255741
# 54           54               Elberfeld              51.255741
# 55           55               Elberfeld              51.255741
# 56           56               Elberfeld              51.255741
# 57           57               Elberfeld              51.255741
# 58           58               Elberfeld              51.255741
# 59           59               Elberfeld              51.255741
# 60           60               Elberfeld              51.255741
# 61           61               Elberfeld              51.255741
# 62           62               Elberfeld              51.255741
# 63           63               Elberfeld              51.255741
# 64           64               Elberfeld              51.255741
# 65           65               Elberfeld              51.255741
# 66           66               Nordstadt              51.262271
# 67           67               Nordstadt              51.262271
# 68           68               Nordstadt              51.262271
# 69           69               Nordstadt              51.262271
# 70           70               Nordstadt              51.262271
# 71           71              Ostersbaum              51.263719
# 72           72              Ostersbaum              51.263719
# 73           73              Ostersbaum              51.263719
# 74           74              Ostersbaum              51.263719
# 75           75              Ostersbaum              51.263719
# 76           76                Südstadt              51.252192
# 77           77                Südstadt              51.252192
# 78           78                Südstadt              51.252192
# 79           79                Südstadt              51.252192
# 80           80                Südstadt              51.252192
# 81           81                Südstadt              51.252192
# 82           82                Südstadt              51.252192
# 83           83                Südstadt              51.252192
# 84           84                Südstadt              51.252192
# 85           85                Südstadt              51.252192
# 86           86                Südstadt              51.252192
# 87           87                Südstadt              51.252192
# 88           88                Südstadt              51.252192
# 89           89            Grifflenberg              51.239131
# 90           90            Grifflenberg              51.239131
# 91           91                Sonnborn              51.242142
# 92           92                Sonnborn              51.242142
# 93           93                Sonnborn              51.242142
# 94           94                Sonnborn              51.242142
# 95           95                Sonnborn              51.242142
# 96           96                Sonnborn              51.242142
# 97           97              Varresbeck              51.257115
# 98           98              Varresbeck              51.257115
# 99           99              Nützenberg              51.252173
# 100         100              Nützenberg              51.252173
# 101         101              Nützenberg              51.252173
# 102         102                   Brill              51.257393
# 103         103               Arrenberg              51.249188
# 104         104               Arrenberg              51.249188
# 105         105               Arrenberg              51.249188
# 106         106               Arrenberg              51.249188
# 107         107               Arrenberg              51.249188
# 108         108               Arrenberg              51.249188
# 109         109               Arrenberg              51.249188
# 110         110               Arrenberg              51.249188
# 111         111               Arrenberg              51.249188
# 112         112               Arrenberg              51.249188
# 113         113               Arrenberg              51.249188
# 114         114                     Zoo              51.238718
# 115         115                     Zoo              51.238718
# 116         116                     Zoo              51.238718
# 117         117                     Zoo              51.238718
# 118         118             Buchenhofen              51.225656
# 119         119         Uellendahl-West              51.277557
# 120         120         Uellendahl-West              51.277557
# 121         121         Uellendahl-West              51.277557
# 122         122         Uellendahl-West              51.277557
# 123         123         Uellendahl-West              51.277557
# 124         124                 Dönberg              51.300403
# 125         125                 Dönberg              51.300403
# 126         126           Nevigeser Str              51.273368
# 127         127           Nevigeser Str              51.273368
# 128         128              Siebeneick              51.291642
# 129         129         Vohwinkel-Mitte              51.231423
# 130         130         Vohwinkel-Mitte              51.231423
# 131         131         Vohwinkel-Mitte              51.231423
# 132         132         Vohwinkel-Mitte              51.231423
# 133         133         Vohwinkel-Mitte              51.231423
# 134         134         Vohwinkel-Mitte              51.231423
# 135         135         Vohwinkel-Mitte              51.231423
# 136         136         Vohwinkel-Mitte              51.231423
# 137         137         Vohwinkel-Mitte              51.231423
# 138         138         Vohwinkel-Mitte              51.231423
# 139         139               Osterholz              51.230000
# 140         140                  Tesche              51.239688
# 141         141                  Tesche              51.239688
# 142         142                  Tesche              51.239688
# 143         143                  Tesche              51.239688
# 144         144              Lüntenbeck              51.249762
# 145         145              Lüntenbeck              51.249762
# 146         146           Industriestr.              51.243415
# 147         147           Industriestr.              51.243415
# 148         148                Westring              51.220215
# 149         149                Westring              51.220215
# 150         150                    Höhe              51.218483
# 151         151                    Höhe              51.218483
# 152         152                    Höhe              51.218483
# 153         153          Schrödersbusch              51.225525
# 154         154              Cronenberg              51.203025
# 155         155              Cronenberg              51.203025
# 236         236  Oberbarmen-Schwarzbach              51.277541
# 237         237  Oberbarmen-Schwarzbach              51.277541
# 238         238  Oberbarmen-Schwarzbach              51.277541
# 239         239      Wichlinghausen-Süd              51.281064
# 240         240      Wichlinghausen-Süd              51.281064
# 241         241      Wichlinghausen-Süd              51.281064
# 242         242      Wichlinghausen-Süd              51.281064
# 243         243      Wichlinghausen-Süd              51.281064
# 244         244      Wichlinghausen-Süd              51.281064
# 245         245     Wichlinghausen-Nord              51.286920
# 246         246     Wichlinghausen-Nord              51.286920
# 247         247     Wichlinghausen-Nord              51.286920
# 248         248     Wichlinghausen-Nord              51.286920
# 249         249     Wichlinghausen-Nord              51.286920
# 250         250     Wichlinghausen-Nord              51.286920
# 251         251        Nächstebreck-Ost              51.301531
# 252         252        Nächstebreck-Ost              51.301531
# 253         253        Nächstebreck-Ost              51.301531
# 254         254       Nächstebreck-West              51.297355
# 255         255       Nächstebreck-West              51.297355
# 256         256       Nächstebreck-West              51.297355
# 257         257           Heckinghausen              51.267418
# 258         258           Heckinghausen              51.267418
# 259         259           Heckinghausen              51.267418
# 260         260           Heckinghausen              51.267418
# 261         261                   Heidt              51.263809
# 262         262              Hammesberg              51.254444
# 263         263        Langerfeld-Mitte              51.274339
# 264         264        Langerfeld-Mitte              51.274339
# 265         265        Langerfeld-Mitte              51.274339
# 266         266        Langerfeld-Mitte              51.274339
# 267         267                Rauental              51.267165
# 268         268                Rauental              51.267165
# 269         269                Rauental              51.267165
# 270         270                Rauental              51.267165
# 271         271                Rauental              51.267165
# 272         272       Jesinghauser Str.              51.280918
# 273         273       Jesinghauser Str.              51.280918
# 274         274       Jesinghauser Str.              51.280918
# 275         275       Jesinghauser Str.              51.280918
# 276         276             Hilgershöhe              51.282507
# 277         277             Hilgershöhe              51.282507
# 278         278             Hilgershöhe              51.282507
# 279         279             Hilgershöhe              51.282507
# 280         280                  Fleute              51.279609
# 281         281                  Fleute              51.279609
# 282         282                  Fleute              51.279609
# 283         283                  Fleute              51.279609
# 284         284                  Fleute              51.279609
# 285         285                  Fleute              51.279609
# 286         286               Ehrenberg              51.264944
# 287         287         Beyenburg-Mitte              51.247613
# 288         288         Beyenburg-Mitte              51.247613
# 289         289     Ronsdorf-Mitte/Nord              51.233069
# 290         290     Ronsdorf-Mitte/Nord              51.233069
# 291         291      Blombach-Lohsiepen              51.231021
# 292         292      Blombach-Lohsiepen              51.231021
# 293         293              Schenkstr.              51.220951
# 294         294              Schenkstr.              51.220951
# 295         295              Schenkstr.              51.220951
# 296         296               Blutfinke              51.220013
# 297         297          Erbschlö-Linde              51.238855
#
#      Neighborhood Longitude  \
# 0                  7.146831
# 1                  7.146831
# 2                  7.146831
# 3                  7.146831
# 4                  7.146831
# 5                  7.146831
# 6                  7.146831
# 7                  7.146831
# 8                  7.146831
# 9                  7.146831
# 10                 7.146831
# 11                 7.146831
# 12                 7.146831
# 13                 7.146831
# 14                 7.146831
# 15                 7.146831
# 16                 7.146831
# 17                 7.146831
# 18                 7.146831
# 19                 7.146831
# 20                 7.146831
# 21                 7.146831
# 22                 7.146831
# 33                                                                         C&A
# 34                                                       Don Camillo & Peppone
# 35                                                                   kapadokya
# 36                                                                    Rossmann
# 37                                                                Telekom Shop
# 38                                                          Eis-Café Mandoliti
# 39                                                             Firenze Eiscafé
# 40                                                   InterCity Hotel Wuppertal
# 41                                                                         H&M
# 42                                                                     Primark
# 43                                                                    BackWerk
# 44                                                                       Kamps
# 45                                                        Von der Heydt-Museum
# 46                                                                        MIO3
# 47                                                               Deutsche Bank
# 48                                                                    Rossmann
# 49                                                                     akzenta
# 50                                                                      Saturn
# 51                                                               Central-Hotel
# 52                                                             Rathaus Galerie
# 53                                                    Galeria Karstadt Kaufhof
# 54                                                              Bäckerei Büsch
# 55                                                                     TK Maxx
# 56                                                                City-Arkaden
# 57                                                                   Kittichai
# 58                                                                     Gleis 1
# 59                                                                   Gleis 2/3
# 60                                                                   Gleis 4/5
# 61                                           EDEKA Frischemarkt Rathausgalerie
# 62                                                               H Ohligsmühle
# 63                                                 H Ohligsmühle (Schwebebahn)
# 64                                                                   Donatello
# 65                                                Wuppertal Hauptbahnhof (ZOB)
# 66                                                                       Hayat
# 67                                                                      Domhan
# 68                                                             Mangal Ocakbasi
# 69                                                                  New Yorker
# 70                                                             Café Marrakesch
# 71                                                                Hardt-Anlage
# 72                                                          Botanischer Garten
# 73                                                                  Café Elise
# 74                                                          Platz der Republik
# 75                                                                       PENNY
# 76                                                           dm-drogerie markt
# 77                                                                  REWE To Go
# 78                                                                        REWE
# 79                                                   InterCity Hotel Wuppertal
# 80                                                                       Kamps
# 81                                                             Kati's Postshop
# 82                                                                     Primark
# 83                                                              Bäckerei Büsch
# 84                                                                    BackWerk
# 85                                                               H Blankstraße
# 86                                                                   Pinocchio
# 87                                                Wuppertal Hauptbahnhof (ZOB)
# 88                                        H Kluse/Schauspielhaus (Schwebebahn)
# 89                                                        H Campus Freudenberg
# 90                                                 Albert Einstein Straße 0815
# 91                                                              Stadion am Zoo
# 92                                                        S Wuppertal-Sonnborn
# 93                                                   Sonnborner Kreuz (31) (6)
# 94                                                 H Zoo/Stadion (Schwebebahn)
# 95                                                                 Pizza Nicos
# 96                                          H Sonnborner Straße  (Schwebebahn)
# 97                                                                Cafe Kirberg
# 98                                                       Spielplatz Pahlkestr.
# 99                                                AS Wuppertal-Varresbeck (32)
# 100                                                               Anilintreppe
# 101                                                                   La Bella
# 102                                                                  ALDI NORD
# 103                                                                     Simonz
# 104                                                                   Tai Lake
# 105                                                          Alte Papierfabrik
# 106                                                                        OBI
# 107                                                                     SUBWAY
# 108                                                             McDreams Hotel
# 109                                                                 McDonald's
# 110                                                                alem Market
# 111                                           H Pestalozzistraße (Schwebebahn)
# 112                                         Enchilada Puro Mexico Bar Mexicano
# 113                                                       Sport Park Elberfeld
# 114                                              Zoologischer Garten Wuppertal
# 115                                                                   Okavango
# 116                                                Elefantenhaus Zoo Wuppertal
# 117                                              Da Vinci - Zum alten Kuhstall
# 118                                            Kinder und Jugendfarm Wuppertal
# 119                                                          Arnold Drost GmbH
# 120                                                                       Lidl
# 121                         TopJob Agentur für Personalberatung & -vermittlung
# 207                                                                   Tacheles
# 208                                                             Feuer & Flamme
# 209                                                        Orchesterprobenraum
# 210                                                               Bismarckturm
# 211                                          H Völklinger Straße (Schwebebahn)
# 212                                          Schoener Grillplatz an der Wupper
# 213                                                              Liquid Helden
# 214                                       Francisca Günther Krankenpflege GmbH
# 215                                                             Nordbahntrasse
# 216                                                                    Propers
# 217                                                            Dolce & Falcone
# 218                                                              Göreme Market
# 219                                                         Schönebecker Busch
# 220                                                                akkus pizza
# 221                                                                    Rubarth
# 222                                                                Private Gym
# 223                                                          Thepa Hausdienste
# 224                                                             Mein Thermomix
# 225                                                              Kothener Wald
# 226                                                             Kothener Busch
# 227                                                      WingTsun Schule Pusse
# 228                                                 Skulpturenpark Waldfrieden
# 229                                                                Café Podest
# ...
# 96        51.237974         7.095408                   Cable Car        Rest
# 97        51.256044         7.097138                      Bakery        Rest
# 98        51.260083         7.100397                  Playground        Rest
# 99        51.252770         7.107027                Intersection  Unfriendly
# 100       51.250395         7.117439                       Trail    Activity
# 101       51.253433         7.104993          Turkish Restaurant        Rest
# 102       51.256597         7.131011                 Supermarket        Rest
# 103       51.248482         7.129493                   Gastropub  Unfriendly
# 104       51.250090         7.129727          Chinese Restaurant        Rest
# 105       51.252307         7.128973                Cocktail Bar  Unfriendly
# 106       51.248398         7.135303              Hardware Store        Rest
# 107       51.250986         7.128411              Sandwich Place        Rest
# 108       51.250375         7.128888                       Hotel        Rest
# 109       51.250866         7.128811        Fast Food Restaurant        Rest
# 110       51.250345         7.126217           Food & Drink Shop        Rest
# 111       51.248650         7.125496                   Cable Car        Rest
# 112       51.252195         7.129079          Mexican Restaurant        Rest
# 113       51.252585         7.129038                         Gym        Rest
# 114       51.240883         7.109417                         Zoo    Activity
# 115       51.239111         7.109480                 Snack Place        Rest
# 116       51.239076         7.109293                 Zoo Exhibit    Activity
# 117       51.240518         7.106005                  Restaurant        Rest
# 118       51.229338         7.104116                        Farm        Rest
# 119       51.278478         7.148427  Construction & Landscaping        Rest
# 120       51.277267         7.151890                 Supermarket        Rest
# 121       51.280935         7.148352            Business Service        Rest
# 122       51.281770         7.149477     Health & Beauty Service        Rest
# 123       51.273504         7.152103                  Print Shop        Rest
# 124       51.299797         7.155801           German Restaurant        Rest
# 125       51.303560         7.155070  Construction & Landscaping        Rest
# 126       51.271648         7.124516                 Pizza Place        Rest
# 127       51.270982         7.125050                      Bakery        Rest
# 128       51.289891         7.116372             Nature Preserve        Rest
# 129       51.231515         7.071100                        Café        Rest
# 130       51.231997         7.068909                 Supermarket        Rest
# 131       51.230253         7.067816                      Bakery        Rest
# 132       51.233582         7.074876               Big Box Store        Rest
# 133       51.229850         7.074340                 Gas Station        Rest
# 134       51.231640         7.067230                   Drugstore        Rest
# 135       51.233224         7.076686                 Supermarket        Rest
# 136       51.233631         7.071984                      Bakery        Rest
# 137       51.230329         7.067885                   Cable Car        Rest
# 138       51.230093         7.067343            Doner Restaurant        Rest
# 139       51.227870         7.053220  Construction & Landscaping        Rest
# 140       51.240150         7.070160                   Pet Store        Rest
# 203       51.264329         7.180481                Liquor Store  Unfriendly
# 204       51.264112         7.178446                 Supermarket        Rest
# 205       51.267137         7.181233                   Cable Car        Rest
# 206       51.264707         7.174169                       Hotel        Rest
# 207       51.269242         7.174688                        Café        Rest
# 208       51.264360         7.176620             Warehouse Store        Rest
# 209       51.268157         7.166415                 Music Venue        Rest
# 210       51.263450         7.167199         Monument / Landmark        Rest
# 211       51.262430         7.173864                   Cable Car        Rest
# 212       51.262143         7.170807                       Plaza    Activity
# 213       51.270954         7.168778                 Supermarket        Rest
# 214       51.272943         7.174702                Home Service        Rest
# 215       51.270425         7.179859                       Trail    Activity
# 216       51.273651         7.184975           Recreation Center        Rest
# 217       51.273948         7.186778                        Café        Rest
# 218       51.271206         7.183188               Grocery Store        Rest
# 219       51.273460         7.181635                      Forest        Rest
# 220       51.275902         7.186752                 Pizza Place        Rest
# 221       51.276006         7.187146          Spanish Restaurant        Rest
# 222       51.279426         7.195468                         Gym        Rest
# 223       51.290850         7.185081  Construction & Landscaping        Rest
# 224       51.288199         7.179084           Electronics Store        Rest
# 225       51.260495         7.182296                        Park    Activity
# 226       51.260560         7.182202                        Park    Activity
# 227       51.263135         7.185003         Martial Arts School        Rest
# 228       51.252807         7.167385            Sculpture Garden    Activity
# 229       51.252772         7.167087                        Café        Rest
# 230       51.248001         7.192037        Fast Food Restaurant        Rest
# 231       51.274926         7.222897                   BBQ Joint        Rest
# 232       51.274903         7.217965                 Supermarket        Rest
# 233       51.273810         7.221515               Train Station  Unfriendly
# 234       51.274923         7.222440                       Plaza    Activity
# 235       51.274349         7.221724        Fast Food Restaurant        Rest
# 236       51.274592         7.222212                    Bus Stop        Rest
# 237       51.273944         7.221601                    Platform        Rest
# 238       51.274938         7.225335                    Bus Stop        Rest
# 239       51.280792         7.215304  Construction & Landscaping        Rest
# 240       51.282181         7.215779              Ice Cream Shop        Rest
# 241       51.282800         7.214889                    Bus Stop        Rest
# 242       51.283231         7.214861                       Plaza    Activity
# 243       51.278974         7.221625          Rock Climbing Spot        Rest
# 244       51.281848         7.209206                  Hookah Bar  Unfriendly
# 245       51.287226         7.213214                        Food        Rest
# 246       51.287038         7.216864                    Bus Stop        Rest
# 247       51.287179         7.217894                      Bakery        Rest
# 248       51.288301         7.219119                    Bus Stop        Rest
# 249       51.289703         7.219427                    Beer Bar  Unfriendly
# 250       51.283231         7.214861                       Plaza    Activity
# 251       51.302560         7.251304                       Hotel        Rest
# 252       51.302619         7.251934    Mediterranean Restaurant        Rest
# 253       51.297444         7.245790  Construction & Landscaping        Rest
# 254       51.296867         7.222282           German Restaurant        Rest
# 255       51.296065         7.214529                   Rest Area        Rest
# 256       51.295426         7.221652                  Print Shop        Rest
# 257       51.270887         7.222203                      Bakery        Rest
# 258       51.271030         7.221831            Asian Restaurant        Rest
# 259       51.270973         7.224472                       Diner        Rest
# 260       51.270588         7.226472                  Hobby Shop        Rest
# 261       51.259817         7.203972                       Plaza    Activity
# 262       51.254810         7.221282                    Bus Stop        Rest
# 263       51.274141         7.238752                 Gas Station        Rest
# 264       51.274051         7.241379            Insurance Office        Rest
# 265       51.274090         7.243318                         ATM        Rest
# 266       51.277836         7.242110               Train Station  Unfriendly
# 267       51.268553         7.236013                Climbing Gym    Activity
# 268       51.264699         7.237314                     Theater    Activity
# 269       51.270294         7.234764                Soccer Field    Activity
# 270       51.267494         7.231361                        Café        Rest
# 271       51.268948         7.231376                       Hotel        Rest
# 272       51.280862         7.242166                 Supermarket        Rest
# 273       51.280937         7.240719      Furniture / Home Store        Rest
# 274       51.277836         7.242110               Train Station  Unfriendly
# 275       51.276629         7.247944           Electronics Store        Rest
# 276       51.284444         7.231677                      Garden        Rest
# 277       51.280937         7.240719      Furniture / Home Store        Rest
# 278       51.280822         7.241937                 Supermarket        Rest
# 279       51.280862         7.242166                 Supermarket        Rest
# 280       51.282815         7.256955         Fried Chicken Joint        Rest
# 281       51.282485         7.254823        Gym / Fitness Center        Rest
# 282       51.282689         7.255424          Chinese Restaurant        Rest
# 283       51.277116         7.258221             Automotive Shop        Rest
# 284       51.283278         7.258104                Intersection  Unfriendly
# 285       51.282848         7.255821                 Gas Station        Rest
# 286       51.266061         7.249672        Fast Food Restaurant        Rest
# 287       51.245154         7.286650                Camera Store        Rest
# 288       51.248487         7.291155                    Bus Stop        Rest
# 289       51.232373         7.193760                 Gas Station        Rest
# 290       51.230593         7.188316           Recreation Center        Rest
# 291       51.231270         7.209924      Furniture / Home Store        Rest
# 292       51.227270         7.212894                Camera Store        Rest
# 293       51.218081         7.208716  Construction & Landscaping        Rest
# 294       51.224798         7.205893            Greek Restaurant        Rest
# 295       51.218013         7.211832            Business Service        Rest
# 296       51.219223         7.183535                        Lake    Activity
# 297       51.238136         7.227358                Home Service        Rest

# %%
# one hot encoding
wuppertal_onehot = pd.get_dummies(wuppertal_venues['Category'], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
wuppertal_onehot['Neighborhood'] = wuppertal_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [wuppertal_onehot.columns[-1]] + list(wuppertal_onehot.columns[:-1])
wuppertal_onehot = wuppertal_onehot[fixed_columns]
wuppertal_onehot.drop("Rest", axis=1, inplace=True)

wuppertal_onehot.head()
# Out:
#   Neighborhood  Activity  Unfriendly
# 0    Elberfeld         0           0
# 1    Elberfeld         0           0
# 2    Elberfeld         0           0
# 3    Elberfeld         0           0
# 4    Elberfeld         0           0

# %%
wuppertal_grouped = wuppertal_onehot.groupby('Neighborhood').mean().reset_index()
wuppertal_grouped
# Out:
#               Neighborhood  Activity  Unfriendly
# 0                Arrenberg  0.000000    0.181818
# 1             Barmen-Mitte  0.052632    0.000000
# 2               Berghausen  0.000000    0.000000
# 3          Beyenburg-Mitte  0.000000    0.000000
# 4       Blombach-Lohsiepen  0.000000    0.000000
# 5                Blutfinke  1.000000    0.000000
# 6                    Brill  0.000000    0.000000
# 7              Buchenhofen  0.000000    0.000000
# 8                  Clausen  0.000000    0.000000
# 9               Cronenberg  0.250000    0.125000
# 10              Cronenfeld  0.000000    0.000000
# 11                 Dönberg  0.000000    0.000000
# 12               Ehrenberg  0.000000    0.000000
# 13               Elberfeld  0.015152    0.045455
# 14          Erbschlö-Linde  0.000000    0.000000
# 15                  Fleute  0.000000    0.166667
# 16        Fr.-Engels-Allee  0.000000    0.200000
# 17            Grifflenberg  0.000000    0.500000
# 18              Hahnerberg  0.000000    0.000000
# 19              Hammesberg  0.000000    0.000000
# 20                Hatzfeld  0.000000    0.000000
# 21           Heckinghausen  0.000000    0.000000
# 22                   Heidt  1.000000    0.000000
# 23             Hesselnberg  0.500000    0.000000
# 24             Hilgershöhe  0.000000    0.000000
# 25                    Höhe  0.000000    0.000000
# 26           Industriestr.  0.000000    0.000000
# 27       Jesinghauser Str.  0.000000    0.250000
# 28               Kohlfurth  0.000000    0.000000
# 29                  Kothen  0.666667    0.000000
# 30              Küllenhahn  0.000000    0.000000
# 31        Langerfeld-Mitte  0.000000    0.250000
# 32            Lichtenplatz  0.000000    0.000000
# 33                     Loh  0.142857    0.000000
# 34              Lüntenbeck  0.000000    0.000000
# 35           Nevigeser Str  0.000000    0.000000
# 36               Nordstadt  0.000000    0.400000
# 37        Nächstebreck-Ost  0.000000    0.000000
# 38       Nächstebreck-West  0.000000    0.000000
# 39              Nützenberg  0.333333    0.333333
# 40  Oberbarmen-Schwarzbach  0.125000    0.125000
# 41               Osterholz  0.000000    0.000000
# 42              Ostersbaum  0.600000    0.000000
# 43                Rauental  0.600000    0.000000
# 44     Ronsdorf-Mitte/Nord  0.000000    0.000000
# 45                    Rott  0.142857    0.000000
# 46              Schenkstr.  0.000000    0.000000
# 47          Schrödersbusch  0.000000    1.000000
# 48              Sedansberg  0.000000    0.000000
# 49              Siebeneick  0.000000    0.000000
# 50                Sonnborn  0.000000    0.333333
# 51                 Sudberg  0.333333    0.333333
# 52                Südstadt  0.000000    0.000000
# 53                  Tesche  0.000000    0.250000
# 54         Uellendahl-West  0.000000    0.000000
# 55              Varresbeck  0.000000    0.000000
# 56         Vohwinkel-Mitte  0.000000    0.000000
# 57                Westring  0.000000    0.000000
# 58     Wichlinghausen-Nord  0.166667    0.166667
# 59      Wichlinghausen-Süd  0.166667    0.166667
# 60                     Zoo  0.500000    0.000000

# %%
wuppertal_grouped2 = pd.merge(d_wiki[["Neighborhood", "Unemployment_Rate", "Schools"]], wuppertal_grouped, on="Neighborhood", how="left")

# %% [markdown]
# ## Adding livinghouses / population as marker for wealth

# %%
wealth_df = d_wiki[["Neighborhood", "Residents", "Livinghouses", "Population_Density"]].copy()
wealth_df["Houses_per_resident"] = wealth_df["Livinghouses"] / wealth_df["Residents"]
wealth_df.drop(["Residents", "Livinghouses"], axis=1, inplace=True)
wealth_df.sort_values(by="Houses_per_resident", ascending=False)
# Out:
#               Neighborhood  Population_Density  Houses_per_resident
# 62          Herbringhausen                 135             0.368881
# 12             Buchenhofen                  75             0.318182
# 35               Kohlfurth                 489             0.317518
# 19              Siebeneick                 467             0.311149
# 25           Industriestr.                 280             0.306122
# 17                    Beek                1700             0.302185
# 24              Lüntenbeck                 843             0.296496
# 30              Küllenhahn                 381             0.280607
# 34                 Sudberg                 645             0.266878
# 61         Beyenburg-Mitte                1231             0.257789
# 23         Schöller-Dornap                 370             0.257439
# 33              Berghausen                1904             0.246575
# 68          Erbschlö-Linde                 164             0.245215
# 26                Westring                1734             0.243767
# 15                 Dönberg                 795             0.238489
# 53              Hammesberg                 586             0.237189
# 31              Hahnerberg                1825             0.236779
# 60               Ehrenberg                 482             0.232143
# 67               Blutfinke                1190             0.227620
# 45            Lichtenplatz                1166             0.217958
# 29              Cronenberg                1151             0.217519
# 28          Schrödersbusch                 303             0.211382
# 64      Blombach-Lohsiepen                1939             0.208699
# 42                Hatzfeld                1431             0.203445
# 49        Nächstebreck-Ost                 838             0.195391
# 66              Schenkstr.                3827             0.192509
# 18                Eckbusch                 867             0.189595
# 8               Nützenberg                3777             0.184973
# 14          Uellendahl-Ost                2686             0.183972
# 7               Varresbeck                1690             0.183729
# 63     Ronsdorf-Mitte/Nord                2165             0.181222
# 16           Nevigeser Str                2904             0.176945
# 50       Nächstebreck-West                2527             0.173648
# 32              Cronenfeld                1474             0.172958
# 21               Osterholz                2072             0.164943
# 39                 Clausen                2485             0.164540
# 11                     Zoo                1669             0.162749
# 13         Uellendahl-West                3732             0.161482
# 55                Rauental                3458             0.161351
# 56       Jesinghauser Str.                2995             0.157243
# 9                    Brill                3618             0.157000
# 22                  Tesche                2919             0.141907
# 57             Hilgershöhe                7006             0.137675
# 6                 Sonnborn                3929             0.135978
# 20         Vohwinkel-Mitte                6179             0.135265
# 4             Grifflenberg                2628             0.133122
# 43                  Kothen                4826             0.124104
# 54        Langerfeld-Mitte                6855             0.124102
# 44             Hesselnberg                2315             0.123676
# 48     Wichlinghausen-Nord                6716             0.123200
# 38                     Loh                4572             0.122661
# 52                   Heidt                4809             0.115064
# 0                Elberfeld                5352             0.112630
# 41              Sedansberg                5812             0.110877
# 51           Heckinghausen                6954             0.110440
# 27                    Höhe                4569             0.109078
# 40                    Rott               12943             0.108773
# 47      Wichlinghausen-Süd               12648             0.106684
# 59                  Fleute                1946             0.103697
# 5           Friedrichsberg                2698             0.101411
# 2               Ostersbaum               10811             0.094913
# 1                Nordstadt               14635             0.094794
# 10               Arrenberg                6336             0.094696
# 46  Oberbarmen-Schwarzbach                8675             0.094613
# 58               Löhrerlen                2136             0.088656
# 37        Fr.-Engels-Allee                7240             0.087177
# 65               Rehsiepen                2069             0.084205
# 36            Barmen-Mitte                8798             0.079991
# 3                 Südstadt               16339             0.079979

# %%
wuppertal_grouped3 = wuppertal_grouped2.merge(wealth_df, on="Neighborhood", how="left").fillna(0)

# %% [markdown]
# ### Running the clustering algorythm

# %%
# set number of clusters
kclusters = 10

wuppertal_grouped_clustering = wuppertal_grouped3.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(wuppertal_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([8, 5, 9, 5, 0, 0, 6, 7, 6, 6], dtype=int32)

# %% [markdown]
# ### Merging and visualization
# First let's merge the relevant into one frame and look at the means per cluster.

# %%
wuppertal_merged = pd.merge(d_wiki[["Neighborhood", "Latitude", "Longitude"]], wuppertal_grouped3, on="Neighborhood", how="left")

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
#wuppertal_merged = wuppertal_merged.merge(wealth_df, on="Neighborhood", how="left")

# add clustering labels
wuppertal_merged.insert(0, 'Cluster Labels', kmeans.labels_)

wuppertal_merged.sort_values(by="Cluster Labels").head() # check the last columns!
# Out:
#     Cluster Labels         Neighborhood   Latitude  Longitude  \
# 50               0    Nächstebreck-West  51.297355   7.218246
# 63               0  Ronsdorf-Mitte/Nord  51.233069   7.188286
# 39               0              Clausen  51.273361   7.170245
# 14               0       Uellendahl-Ost  51.285533   7.164066
# 4                0         Grifflenberg  51.239131   7.157117
#
#     Unemployment_Rate  Schools  Activity  Unfriendly  Population_Density  \
# 50             0.0383        2       0.0         0.0                2527
# 63             0.0269        1       0.0         0.0                2165
# 39             0.0451        1       0.0         0.0                2485
# 14             0.0431        2       0.0         0.0                2686
# 4              0.0321        1       0.0         0.5                2628
#
#     Houses_per_resident
# 50             0.173648
# 63             0.181222
# 39             0.164540
# 14             0.183972
# 4              0.133122

# %%
df_merged = wuppertal_merged.drop(["Latitude", "Longitude"], 1).groupby("Cluster Labels").mean()
df_merged
# Out:
#                 Unemployment_Rate   Schools  Activity  Unfriendly  \
# Cluster Labels
# 0                        0.047700  1.500000  0.050000    0.100000
# 1                        0.082200  5.000000  0.154762    0.083333
# 2                        0.091400  2.500000  0.088816    0.062500
# 3                        0.025531  0.625000  0.020833    0.083333
# 4                        0.073488  2.500000  0.020833    0.099811
# 5                        0.083450  4.500000  0.000000    0.200000
# 6                        0.050217  1.333333  0.155556    0.111111
# 7                        0.035959  0.882353  0.102941    0.017157
# 8                        0.068200  1.800000  0.364935    0.009091
# 9                        0.096700  4.000000  0.600000    0.000000
#
#                 Population_Density  Houses_per_resident
# Cluster Labels
# 0                      2632.200000             0.153769
# 1                     12795.500000             0.107729
# 2                      8736.500000             0.087302
# 3                       482.500000             0.267042
# 4                      6637.250000             0.115429
# 5                     15487.000000             0.087387
# 6                      3723.500000             0.165549
# 7                      1666.294118             0.195487
# 8                      4825.600000             0.116707
# 9                     10811.000000             0.094913

# %%
# create map
map_clusters = folium.Map(location=[51.256214, 7.150764], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(wuppertal_merged['Latitude'], wuppertal_merged['Longitude'], wuppertal_merged['Neighborhood'], wuppertal_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a1253be072b645b48dfdbf31b8f55c8d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a1253be072b645b48dfdbf31b8f55c8d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a1253be072b645b48dfdbf31b8f55c8d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a1253be072b645b48dfdbf31b8f55c8d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B51.256214%2C%207.150764%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## Results section

# %% [markdown]
# For interpretation of our results, we'll rank the clusters in each category and then reflect the total score by using a weighted sum on these ranks.

# %%
df_merged
# Out:
#                 Unemployment_Rate   Schools  Activity  Unfriendly  \
# Cluster Labels
# 0                        0.047700  1.500000  0.050000    0.100000
# 1                        0.082200  5.000000  0.154762    0.083333
# 2                        0.091400  2.500000  0.088816    0.062500
# 3                        0.025531  0.625000  0.020833    0.083333
# 4                        0.073488  2.500000  0.020833    0.099811
# 5                        0.083450  4.500000  0.000000    0.200000
# 6                        0.050217  1.333333  0.155556    0.111111
# 7                        0.035959  0.882353  0.102941    0.017157
# 8                        0.068200  1.800000  0.364935    0.009091
# 9                        0.096700  4.000000  0.600000    0.000000
#
#                 Population_Density  Houses_per_resident
# Cluster Labels
# 0                      2632.200000             0.153769
# 1                     12795.500000             0.107729
# 2                      8736.500000             0.087302
# 3                       482.500000             0.267042
# 4                      6637.250000             0.115429
# 5                     15487.000000             0.087387
# 6                      3723.500000             0.165549
# 7                      1666.294118             0.195487
# 8                      4825.600000             0.116707
# 9                     10811.000000             0.094913

# %%
df_ranked = df_merged.rank()

# %%
df_ranked["Schools"] = df_ranked["Schools"].max() - df_ranked["Schools"] + 1
df_ranked["Activity"] = df_ranked["Activity"].max() - df_ranked["Activity"] + 1
df_ranked["Houses_per_resident"] = df_ranked["Houses_per_resident"].max() - df_ranked["Houses_per_resident"] + 1

weights = [1.2, 0.5, 1, 0.5, 0.8, 0.8]
df_ranked["Total_rank"] = df_ranked.dot(weights).rank()

# %%
df_ranked.sort_values(by="Total_rank")
# Out:
#                 Unemployment_Rate  Schools  Activity  Unfriendly  \
# Cluster Labels
# 7                             2.0      9.0       5.0         3.0
# 3                             1.0     10.0       8.5         5.5
# 8                             5.0      6.0       2.0         2.0
# 6                             4.0      8.0       3.0         9.0
# 0                             3.0      7.0       7.0         8.0
# 9                            10.0      3.0       1.0         1.0
# 1                             7.0      1.0       4.0         5.5
# 4                             6.0      4.5       8.5         7.0
# 2                             9.0      4.5       6.0         4.0
# 5                             8.0      2.0      10.0        10.0
#
#                 Population_Density  Houses_per_resident  Total_rank
# Cluster Labels
# 7                              2.0                  2.0         1.0
# 3                              1.0                  1.0         2.0
# 8                              5.0                  5.0         3.0
# 6                              4.0                  3.0         4.0
# 0                              3.0                  4.0         5.0
# 9                              8.0                  8.0         6.0
# 1                              9.0                  7.0         7.0
# 4                              6.0                  6.0         8.0
# 2                              7.0                 10.0         9.0
# 5                             10.0                  9.0        10.0

# %% [markdown]
# ## Discussion section

# %% [markdown]
# This final result is highly dependent on the weights used. The choice to weight unemployment the highest and schools the lowest is based on trying to find a distance to the city center in order to give kids the space and safety they need.

# %%
map_df = df_ranked["Total_rank"].reset_index(drop=False).merge(wuppertal_merged[["Neighborhood", "Latitude", "Longitude", "Cluster Labels"]], on="Cluster Labels", how="left")
map_df
map_df["Total_rank"].value_counts()
# Out:
# 1.0     17
# 2.0     16
# 5.0     10
# 8.0      8
# 4.0      6
# 3.0      5
# 10.0     2
# 9.0      2
# 7.0      2
# 6.0      1
# Name: Total_rank, dtype: int64

# %%
# let Folium determine the scale.
world_map = folium.Map(location=[51.256214, 7.150764], zoom_start=12)
world_map.choropleth(
    geo_data=geojson,
    data=map_df,
    columns=['Neighborhood', 'Total_rank'],
    key_on='feature.properties.NAME',
    fill_color="YlGnBu", 
    fill_opacity=0.6, 
    line_opacity=0.8,
    legend_name='Cluster',
    bins=[1,2,3,11],
    reset=True
)
world_map
# Out:
# /Users/a1/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a6763deaa6fa44e293671672d09e62b8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a6763deaa6fa44e293671672d09e62b8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a6763deaa6fa44e293671672d09e62b8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a6763deaa6fa44e293671672d09e62b8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Conclusion section

# %% [markdown]
# We can conclude, that cluster 7 is the most suited for young families, based on our criteria.
# This seem to be the neighborhoods in between the center and the outmost districts. This makes sense, as we'd expect the best balance of kids friendly activities and distance from nightlife, industrial zones and high unemployment neighborhoods.
